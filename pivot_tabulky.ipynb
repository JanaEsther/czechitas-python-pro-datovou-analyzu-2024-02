# %%
import pandas as pd
food_nutrient = pd.read_csv("food_nutrient.csv")
branded_food = pd.read_csv("branded_food.csv")
# Out:
# C:\Users\Jana Obendraufova\AppData\Local\Temp\ipykernel_4344\3534465747.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
url_food_nutrient = "https://kodim.cz/cms/assets/czechitas/python-data-1/python-pro-data-1/podmineny-vyber/podmineny-vyber/food_nutrient.csv"

food_nutrient = pd.read_csv(url_food_nutrient)
food_nutrient.head(15)
# Out:
#      fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  \
# 0   1106032         1257     NaN          NaN           71.0  NaN  NaN
# 1   1107191         1257     NaN          NaN           70.0  NaN  NaN
# 2   1107295         1257     NaN          NaN           70.0  NaN  NaN
# 3   1107475         1257     NaN          NaN           70.0  NaN  NaN
# 4   1107528         1257     0.0          NaN           70.0  NaN  NaN
# 5   1108007         1257     0.0          NaN           70.0  NaN  NaN
# 6   1108158         1257     0.0          NaN           70.0  NaN  NaN
# 7   1108349         1257     0.0          NaN           70.0  NaN  NaN
# 8   1108803         1257     0.0          NaN           70.0  NaN  NaN
# 9   1108908         1257     0.0          NaN           70.0  NaN  NaN
# 10  1109116         1257     0.0          NaN           70.0  NaN  NaN
# 11  1109336         1257     0.0          NaN           70.0  NaN  NaN
# 12  1109393         1257     0.0          NaN           70.0  NaN  NaN
# 13  1109400         1257     0.0          NaN           70.0  NaN  NaN
# 14  1109434         1257     0.0          NaN           70.0  NaN  NaN
#
#     median  loq  footnote  min_year_acquired                      name  \
# 0      NaN  NaN       NaN                NaN  Fatty acids, total trans
# 1      NaN  NaN       NaN                NaN  Fatty acids, total trans
# 2      NaN  NaN       NaN                NaN  Fatty acids, total trans
# 3      NaN  NaN       NaN                NaN  Fatty acids, total trans
# 4      NaN  NaN       NaN                NaN  Fatty acids, total trans
# 5      NaN  NaN       NaN                NaN  Fatty acids, total trans
# 6      NaN  NaN       NaN                NaN  Fatty acids, total trans
# 7      NaN  NaN       NaN                NaN  Fatty acids, total trans
# 8      NaN  NaN       NaN                NaN  Fatty acids, total trans
# 9      NaN  NaN       NaN                NaN  Fatty acids, total trans
# 10     NaN  NaN       NaN                NaN  Fatty acids, total trans
# 11     NaN  NaN       NaN                NaN  Fatty acids, total trans
# 12     NaN  NaN       NaN                NaN  Fatty acids, total trans
# 13     NaN  NaN       NaN                NaN  Fatty acids, total trans
# 14     NaN  NaN       NaN                NaN  Fatty acids, total trans
#
#    unit_name
# 0          G
# 1          G
# 2          G
# 3          G
# 4          G
# 5          G
# 6          G
# 7          G
# 8          G
# 9          G
# 10         G
# 11         G
# 12         G
# 13         G
# 14         G

# %%
food_nutrient = food_nutrient.drop_duplicates(subset=["fdc_id", "name"])

# %%
food_nutrient_pivot = pd.pivot(food_nutrient, index="fdc_id", columns="name", values="amount")
food_nutrient_pivot.head()
# Out:
# name     Ergosta-5,7-dienol  25-hydroxycholecalciferol  Alanine  \
# fdc_id
# 167551                  NaN                        NaN    0.392
# 167711                  NaN                        NaN      NaN
# 168370                  NaN                        NaN    1.782
# 168460                  NaN                        NaN    0.355
# 168526                  NaN                        NaN      NaN
#
# name    Alcohol, ethyl  Arginine   Ash  Aspartic acid  Beta-glucan  \
# fdc_id
# 167551             0.0     0.489  1.80          0.572          NaN
# 167711             0.0       NaN  0.58            NaN          NaN
# 168370             0.0     2.004  1.14          2.910          NaN
# 168460             0.0     0.585  1.10          1.148          NaN
# 168526             NaN     0.222  1.24            NaN          NaN
#
# name    Beta-sitostanol  Beta-sitosterol  ...  Vitamin K (phylloquinone)  \
# fdc_id                                    ...
# 167551              NaN              NaN  ...                        3.9
# 167711              NaN              NaN  ...                        0.1
# 168370              NaN              NaN  ...                        0.0
# 168460              NaN              NaN  ...                       70.6
# 168526              NaN              NaN  ...                        NaN
#
# name    Water  Xylitol  Zeaxanthin  Zinc, Zn  cis-Lutein/Zeaxanthin  \
# fdc_id
# 167551   3.30      NaN         NaN      1.24                    NaN
# 167711  87.63      NaN         NaN      0.16                    NaN
# 168370  66.99      NaN         NaN      2.86                    NaN
# 168460  79.45      NaN         NaN      1.04                    NaN
# 168526  75.48      NaN         NaN      1.03                    NaN
#
# name    cis-Lycopene  cis-beta-Carotene  trans-Lycopene  trans-beta-Carotene
# fdc_id
# 167551           NaN                NaN             NaN                  NaN
# 167711           NaN                NaN             NaN                  NaN
# 168370           NaN                NaN             NaN                  NaN
# 168460           NaN                NaN             NaN                  NaN
# 168526           NaN                NaN             NaN                  NaN
#
# [5 rows x 205 columns]

# %%
food = pd.concat([pd.read_csv("food_sample_100.csv"), pd.read_csv("food_other.csv")], ignore_index=True)
branded_food = pd.read_csv("branded_food.csv")
food = pd.concat([pd.read_csv("food_sample_100.csv"), pd.read_csv("food_other.csv")], ignore_index=True)
food_brands = pd.merge(food, branded_food, on="fdc_id")

# %%
food_nutrient_pivot.columns
# Out:
# Index([' Ergosta-5,7-dienol', '25-hydroxycholecalciferol', 'Alanine',
#        'Alcohol, ethyl', 'Arginine', 'Ash', 'Aspartic acid', 'Beta-glucan',
#        'Beta-sitostanol', 'Beta-sitosterol',
#        ...
#        'Vitamin K (phylloquinone)', 'Water', 'Xylitol', 'Zeaxanthin',
#        'Zinc, Zn', 'cis-Lutein/Zeaxanthin', 'cis-Lycopene',
#        'cis-beta-Carotene', 'trans-Lycopene', 'trans-beta-Carotene'],
#       dtype='object', name='name', length=205)

# %%
food_nutrient_pivot.shape
# Out:
# (9987, 205)

# %%
food_nutrient_pivot.head()
# Out:
# name     Ergosta-5,7-dienol  25-hydroxycholecalciferol  Alanine  \
# fdc_id
# 167551                  NaN                        NaN    0.392
# 167711                  NaN                        NaN      NaN
# 168370                  NaN                        NaN    1.782
# 168460                  NaN                        NaN    0.355
# 168526                  NaN                        NaN      NaN
#
# name    Alcohol, ethyl  Arginine   Ash  Aspartic acid  Beta-glucan  \
# fdc_id
# 167551             0.0     0.489  1.80          0.572          NaN
# 167711             0.0       NaN  0.58            NaN          NaN
# 168370             0.0     2.004  1.14          2.910          NaN
# 168460             0.0     0.585  1.10          1.148          NaN
# 168526             NaN     0.222  1.24            NaN          NaN
#
# name    Beta-sitostanol  Beta-sitosterol  ...  Vitamin K (phylloquinone)  \
# fdc_id                                    ...
# 167551              NaN              NaN  ...                        3.9
# 167711              NaN              NaN  ...                        0.1
# 168370              NaN              NaN  ...                        0.0
# 168460              NaN              NaN  ...                       70.6
# 168526              NaN              NaN  ...                        NaN
#
# name    Water  Xylitol  Zeaxanthin  Zinc, Zn  cis-Lutein/Zeaxanthin  \
# fdc_id
# 167551   3.30      NaN         NaN      1.24                    NaN
# 167711  87.63      NaN         NaN      0.16                    NaN
# 168370  66.99      NaN         NaN      2.86                    NaN
# 168460  79.45      NaN         NaN      1.04                    NaN
# 168526  75.48      NaN         NaN      1.03                    NaN
#
# name    cis-Lycopene  cis-beta-Carotene  trans-Lycopene  trans-beta-Carotene
# fdc_id
# 167551           NaN                NaN             NaN                  NaN
# 167711           NaN                NaN             NaN                  NaN
# 168370           NaN                NaN             NaN                  NaN
# 168460           NaN                NaN             NaN                  NaN
# 168526           NaN                NaN             NaN                  NaN
#
# [5 rows x 205 columns]

# %%
food_nutrient_pivot.shape
# Out:
# (9987, 205)

# %%
food_nutrient = food_nutrient.drop_duplicates(subset=["fdc_id", "name"])

# %%
import seaborn as sns

# %%
branded_food.columns
# Out:
# Index(['fdc_id', 'brand_owner', 'brand_name', 'subbrand_name', 'gtin_upc',
#        'ingredients', 'not_a_significant_source_of', 'serving_size',
#        'serving_size_unit', 'household_serving_fulltext',
#        'branded_food_category', 'data_source', 'package_weight',
#        'modified_date', 'available_date', 'market_country',
#        'discontinued_date', 'preparation_state_code', 'trade_channel',
#        'short_description'],
#       dtype='object')

# %%
import seaborn as sns

# %%
branded_food.head()
# Out:
#     fdc_id                brand_owner brand_name subbrand_name  \
# 0  1106032    BRAKEBUSH BROTHERS INC.        NaN           NaN
# 1  1107191                  Mahco Inc        NaN           NaN
# 2  1107295  Hormel Foods Corporation         NaN           NaN
# 3  1107475                HP Hood LLC        NaN           NaN
# 4  1107528            Bar-S Foods Co.        NaN           NaN
#
#          gtin_upc                                        ingredients  \
# 0  10038034720202  INGREDIENTS: BONELESS CHICKEN BREAST MEAT WITH...
# 1    877448001674  TOMATO PUREE (TOMATOES), CARROTS, ONIONS, SUN-...
# 2     37600665605  MASA FLOUR (GROUND WHITE CORN WITH A TRACE OF ...
# 3     73570130330  CULTURED PASTEURIZED MILK, CREAM AND NONFAT MI...
# 4     15900002115  MECHANICALLY SEPARATED CHICKEN, WATER, PORK, D...
#
#   not_a_significant_source_of  serving_size serving_size_unit  \
# 0                         NaN          85.0                 g
# 1                         NaN         125.0                 g
# 2                         NaN          30.0                 g
# 3                         NaN          31.0                 g
# 4                         NaN          56.0                 g
#
#   household_serving_fulltext                           branded_food_category  \
# 0                        NaN  Meat/Poultry/Other Animals  Prepared/Processed
# 1                        NaN                   Prepared Pasta & Pizza Sauces
# 2                        NaN                        Chips, Pretzels & Snacks
# 3                        NaN                                          Cheese
# 4                        NaN                       Sausages, Hotdogs & Brats
#
#   data_source package_weight modified_date available_date market_country  \
# 0        GDSN            NaN    2020-09-03     2020-11-13  United States
# 1          LI            NaN    2020-09-22     2020-11-13  United States
# 2          LI            NaN    2020-04-08     2020-11-13  United States
# 3          LI            NaN    2020-04-08     2020-11-13  United States
# 4          LI            NaN    2020-04-08     2020-11-13  United States
#
#    discontinued_date preparation_state_code trade_channel short_description
# 0                NaN                    NaN           NaN               NaN
# 1                NaN                    NaN           NaN               NaN
# 2                NaN                    NaN           NaN               NaN
# 3                NaN                    NaN           NaN               NaN
# 4                NaN                    NaN           NaN               NaN

# %%
bins = [0, 20, 100, float('inf')]
labels = ['Low Cholesterol', 'Moderate Cholesterol', 'High Cholesterol']
food_nutrient_pivot['Cholesterol Category'] = pd.cut(food_nutrient_pivot['Cholesterol'], bins=bins, labels=labels)
food_nutrient_pivot
# Out:
# name      Ergosta-5,7-dienol  25-hydroxycholecalciferol  Alanine  \
# fdc_id
# 167551                   NaN                        NaN    0.392
# 167711                   NaN                        NaN      NaN
# 168370                   NaN                        NaN    1.782
# 168460                   NaN                        NaN    0.355
# 168526                   NaN                        NaN      NaN
# ...                      ...                        ...      ...
# 2661515                  NaN                        NaN      NaN
# 2661730                  NaN                        NaN      NaN
# 2661782                  NaN                        NaN      NaN
# 2662107                  NaN                        NaN      NaN
# 2662182                  NaN                        NaN      NaN
#
# name     Alcohol, ethyl  Arginine   Ash  Aspartic acid  Beta-glucan  \
# fdc_id
# 167551              0.0     0.489  1.80          0.572          NaN
# 167711              0.0       NaN  0.58            NaN          NaN
# 168370              0.0     2.004  1.14          2.910          NaN
# 168460              0.0     0.585  1.10          1.148          NaN
# 168526              NaN     0.222  1.24            NaN          NaN
# ...                 ...       ...   ...            ...          ...
# 2661515             NaN       NaN   NaN            NaN          NaN
# 2661730             NaN       NaN   NaN            NaN          NaN
# 2661782             NaN       NaN   NaN            NaN          NaN
# 2662107             NaN       NaN   NaN            NaN          NaN
# 2662182             NaN       NaN   NaN            NaN          NaN
#
# name     Beta-sitostanol  Beta-sitosterol  ...  Water  Xylitol  Zeaxanthin  \
# fdc_id                                     ...
# 167551               NaN              NaN  ...   3.30      NaN         NaN
# 167711               NaN              NaN  ...  87.63      NaN         NaN
# 168370               NaN              NaN  ...  66.99      NaN         NaN
# 168460               NaN              NaN  ...  79.45      NaN         NaN
# 168526               NaN              NaN  ...  75.48      NaN         NaN
# ...                  ...              ...  ...    ...      ...         ...
# 2661515              NaN              NaN  ...    NaN      NaN         NaN
# 2661730              NaN              NaN  ...    NaN      NaN         NaN
# 2661782              NaN              NaN  ...    NaN      NaN         NaN
# 2662107              NaN              NaN  ...    NaN      NaN         NaN
# 2662182              NaN              NaN  ...    NaN      NaN         NaN
#
# name     Zinc, Zn  cis-Lutein/Zeaxanthin  cis-Lycopene  cis-beta-Carotene  \
# fdc_id
# 167551       1.24                    NaN           NaN                NaN
# 167711       0.16                    NaN           NaN                NaN
# 168370       2.86                    NaN           NaN                NaN
# 168460       1.04                    NaN           NaN                NaN
# 168526       1.03                    NaN           NaN                NaN
# ...           ...                    ...           ...                ...
# 2661515       NaN                    NaN           NaN                NaN
# 2661730       NaN                    NaN           NaN                NaN
# 2661782       NaN                    NaN           NaN                NaN
# 2662107       NaN                    NaN           NaN                NaN
# 2662182       NaN                    NaN           NaN                NaN
#
# name     trans-Lycopene  trans-beta-Carotene  Cholesterol Category
# fdc_id
# 167551              NaN                  NaN                   NaN
# 167711              NaN                  NaN                   NaN
# 168370              NaN                  NaN  Moderate Cholesterol
# 168460              NaN                  NaN                   NaN
# 168526              NaN                  NaN                   NaN
# ...                 ...                  ...                   ...
# 2661515             NaN                  NaN                   NaN
# 2661730             NaN                  NaN                   NaN
# 2661782             NaN                  NaN                   NaN
# 2662107             NaN                  NaN  Moderate Cholesterol
# 2662182             NaN                  NaN                   NaN
#
# [9987 rows x 206 columns]
