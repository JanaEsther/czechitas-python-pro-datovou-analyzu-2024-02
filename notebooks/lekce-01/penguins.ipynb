# %%
import pandas as pd
# Out:
# C:\Users\Jana Obendraufova\AppData\Local\Temp\ipykernel_21660\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
url = "https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv"


penguins = pd.read_csv('https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv')

print(penguins.head())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
penguins_5000_gt = penguins[penguins["body_mass_g"]== 5000]

# %%
print(penguins_5000_gt.shape[0])
# Out:
# 6

# %%
print(penguins_5000_gt.shape[1])
# Out:
# 8

# %%
penguins_5000_gt
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 173  Gentoo  Biscoe            45.1           14.5              215.0
# 176  Gentoo  Biscoe            42.9           13.1              215.0
# 205  Gentoo  Biscoe            50.1           15.0              225.0
# 209  Gentoo  Biscoe            45.5           15.0              220.0
# 223  Gentoo  Biscoe            46.4           15.6              221.0
# 262  Gentoo  Biscoe            50.5           15.2              216.0
#
#      body_mass_g     sex  year
# 173       5000.0  female  2007
# 176       5000.0  female  2007
# 205       5000.0    male  2008
# 209       5000.0    male  2008
# 223       5000.0    male  2008
# 262       5000.0  female  2009

# %%
penguins['species'].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
penguins[penguins['island']== 'Dream']
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30      Adelie  Dream            39.5           16.7              178.0
# 31      Adelie  Dream            37.2           18.1              178.0
# 32      Adelie  Dream            39.5           17.8              188.0
# 33      Adelie  Dream            40.9           18.9              184.0
# 34      Adelie  Dream            36.4           17.0              195.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 30        3250.0  female  2007
# 31        3900.0    male  2007
# ...

# %%
penguins[penguins["body_mass_g"]> 5000]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# 159  Gentoo  Biscoe            46.7           15.3              219.0
# 161  Gentoo  Biscoe            46.8           15.4              215.0
# ..      ...     ...             ...            ...                ...
# 267  Gentoo  Biscoe            55.1           16.0              230.0
# 269  Gentoo  Biscoe            48.8           16.2              222.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 153       5700.0    male  2007
# 155       5700.0    male  2007
# ...

# %%
penguins[
(penguins["flipper_length_mm"] > 200)&
(penguins["body_mass_g"] < 3500)  
]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 340  Chinstrap  Dream            43.5           18.1              202.0
#
#      body_mass_g     sex  year
# 340       3400.0  female  2009

# %%
penguins[penguins["flipper_length_mm"] > 200]
penguins["body_mass_g"] < 3500
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 90      Adelie      Dream            35.7           18.0              202.0
# 91      Adelie      Dream            41.1           18.1              205.0
# 95      Adelie      Dream            40.8           18.9              208.0
# 101     Adelie     Biscoe            41.0           20.0              203.0
# 123     Adelie  Torgersen            41.4           18.5              202.0
# ..         ...        ...             ...            ...                ...
# 334  Chinstrap      Dream            50.2           18.8              202.0
# 336  Chinstrap      Dream            51.9           19.5              206.0
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins[penguins['year'] == 2007]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 297  Chinstrap      Dream            48.5           17.5              191.0
# 298  Chinstrap      Dream            43.2           16.6              187.0
# 299  Chinstrap      Dream            50.6           19.4              193.0
# 300  Chinstrap      Dream            46.7           17.9              195.0
# 301  Chinstrap      Dream            52.0           19.0              197.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins[penguins['year'] == 2008]
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 50      Adelie  Biscoe            39.6           17.7              186.0
# 51      Adelie  Biscoe            40.1           18.9              188.0
# 52      Adelie  Biscoe            35.0           17.9              190.0
# 53      Adelie  Biscoe            42.0           19.5              200.0
# 54      Adelie  Biscoe            34.5           18.1              187.0
# ..         ...     ...             ...            ...                ...
# 315  Chinstrap   Dream            53.5           19.9              205.0
# 316  Chinstrap   Dream            49.0           19.5              210.0
# 317  Chinstrap   Dream            46.2           17.5              187.0
# 318  Chinstrap   Dream            50.9           19.1              196.0
# 319  Chinstrap   Dream            45.5           17.0              196.0
#
#      body_mass_g     sex  year
# 50        3500.0  female  2008
# ...

# %%
penguins[penguins['year'] == 2009]
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 100     Adelie  Biscoe            35.0           17.9              192.0
# 101     Adelie  Biscoe            41.0           20.0              203.0
# 102     Adelie  Biscoe            37.7           16.0              183.0
# 103     Adelie  Biscoe            37.8           20.0              190.0
# 104     Adelie  Biscoe            37.9           18.6              193.0
# ..         ...     ...             ...            ...                ...
# 339  Chinstrap   Dream            55.8           19.8              207.0
# 340  Chinstrap   Dream            43.5           18.1              202.0
# 341  Chinstrap   Dream            49.6           18.2              193.0
# 342  Chinstrap   Dream            50.8           19.0              210.0
# 343  Chinstrap   Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 100       3725.0  female  2009
# ...

# %%
penguins[penguins["body_mass_g"] < 3500]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 8       Adelie  Torgersen            34.1           18.1              193.0
# 10      Adelie  Torgersen            37.8           17.1              186.0
# 12      Adelie  Torgersen            41.1           17.6              182.0
# ..         ...        ...             ...            ...                ...
# 326  Chinstrap      Dream            48.1           16.4              199.0
# 330  Chinstrap      Dream            42.5           17.3              187.0
# 331  Chinstrap      Dream            52.2           18.8              197.0
# 332  Chinstrap      Dream            45.2           16.6              191.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins["body_mass_g"]== 5000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: body_mass_g, Length: 344, dtype: bool

# %%
Torgersen_females =penguins[(penguins['sex'] == 'female')&(penguins['island'] == 'Torgersen') ]

# %%
print(Torgersen_females.shape[0])
# Out:
# 24

# %%
print(Torgersen_females.shape[1])
# Out:
# 8

# %%
Torgersen_females
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# 15   Adelie  Torgersen            36.6           17.8              185.0
# 16   Adelie  Torgersen            38.7           19.0              195.0
# 18   Adelie  Torgersen            34.4           18.4              184.0
# 68   Adelie  Torgersen            35.9           16.6              190.0
# 70   Adelie  Torgersen            33.5           19.0              190.0
# 72   Adelie  Torgersen            39.6           17.2              196.0
# 74   Adelie  Torgersen            35.5           17.5              190.0
# ...

# %%
unique_species_on_dream_island = penguins[penguins['island'] == 'Dream']['species'].unique()
unique_species_on_dream_island = penguins[penguins['island'] == 'Dream']['species'].unique().tolist()
print(unique_species_on_dream_island )
# Out:
# ['Adelie', 'Chinstrap']

# %%
penguins['species'].unique
# Out:
# <bound method Series.unique of 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object>

# %%
penguins [penguins['species'] == 'Chinstrap']
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
penguins [penguins['island'] == 'Dream']

# %%
penguins[penguins['island']=='Biscoe']
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie  Biscoe            37.8           18.3              174.0
# 21   Adelie  Biscoe            37.7           18.7              180.0
# 22   Adelie  Biscoe            35.9           19.2              189.0
# 23   Adelie  Biscoe            38.2           18.1              185.0
# 24   Adelie  Biscoe            38.8           17.2              180.0
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe             NaN            NaN                NaN
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 20        3400.0  female  2007
# 21        3600.0    male  2007
# ...

# %%
(penguins['species'] == 'Dream') & (penguins['species'] == "Adelie")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
torgersen_sex = penguins[
(penguins['sex'] == 'female')&
(penguins['island'] == 'Torgersen')    
 ]

# %%
torgersen_sex.shape[1]
# Out:
# 8

# %%
torgersen_sex.shape[0]
# Out:
# 24

# %%
torgersen_sex
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# 15   Adelie  Torgersen            36.6           17.8              185.0
# 16   Adelie  Torgersen            38.7           19.0              195.0
# 18   Adelie  Torgersen            34.4           18.4              184.0
# 68   Adelie  Torgersen            35.9           16.6              190.0
# 70   Adelie  Torgersen            33.5           19.0              190.0
# 72   Adelie  Torgersen            39.6           17.2              196.0
# 74   Adelie  Torgersen            35.5           17.5              190.0
# ...

# %%
penguins[
(penguins['sex'] == 'female')&
(penguins['island'] == 'Torgersen')    
 ]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# 15   Adelie  Torgersen            36.6           17.8              185.0
# 16   Adelie  Torgersen            38.7           19.0              195.0
# 18   Adelie  Torgersen            34.4           18.4              184.0
# 68   Adelie  Torgersen            35.9           16.6              190.0
# 70   Adelie  Torgersen            33.5           19.0              190.0
# 72   Adelie  Torgersen            39.6           17.2              196.0
# 74   Adelie  Torgersen            35.5           17.5              190.0
# ...

# %%
penguins[penguins['sex'] == 'female']
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 6       Adelie  Torgersen            38.9           17.8              181.0
# 12      Adelie  Torgersen            41.1           17.6              182.0
# ..         ...        ...             ...            ...                ...
# 335  Chinstrap      Dream            45.6           19.4              194.0
# 337  Chinstrap      Dream            46.8           16.5              189.0
# 338  Chinstrap      Dream            45.7           17.0              195.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins[penguins['island'] == 'Torgersen']
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
penguins.shape[0]
# Out:
# 344

# %%
penguins.shape[1]
# Out:
# 8

# %%
penguins['body_mass_g'].mean()
# Out:
# 4201.754385964912

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
penguins["flipper_length_mm"].describe()
# Out:
# count    342.000000
# mean     200.915205
# std       14.061714
# min      172.000000
# 25%      190.000000
# 50%      197.000000
# 75%      213.000000
# max      231.000000
# Name: flipper_length_mm, dtype: float64

# %%
print(round(penguins["flipper_length_mm"].max(),0))
# Out:
# 231.0

# %%
penguins['year'].unique()
# Out:
# array([2007, 2008, 2009], dtype=int64)

# %%
penguins['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
penguins['species'].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
weight_gt_5000 = penguins[penguins['body_mass_g']> 5000]

# %%
print(weight_gt_5000.shape[0])
# Out:
# 61

# %%
penguins

# %%
penguins[penguins['year']== 2009]
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 100     Adelie  Biscoe            35.0           17.9              192.0
# 101     Adelie  Biscoe            41.0           20.0              203.0
# 102     Adelie  Biscoe            37.7           16.0              183.0
# 103     Adelie  Biscoe            37.8           20.0              190.0
# 104     Adelie  Biscoe            37.9           18.6              193.0
# ..         ...     ...             ...            ...                ...
# 339  Chinstrap   Dream            55.8           19.8              207.0
# 340  Chinstrap   Dream            43.5           18.1              202.0
# 341  Chinstrap   Dream            49.6           18.2              193.0
# 342  Chinstrap   Dream            50.8           19.0              210.0
# 343  Chinstrap   Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 100       3725.0  female  2009
# ...

# %%
penguins[penguins['year']== 2008]
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 50      Adelie  Biscoe            39.6           17.7              186.0
# 51      Adelie  Biscoe            40.1           18.9              188.0
# 52      Adelie  Biscoe            35.0           17.9              190.0
# 53      Adelie  Biscoe            42.0           19.5              200.0
# 54      Adelie  Biscoe            34.5           18.1              187.0
# ..         ...     ...             ...            ...                ...
# 315  Chinstrap   Dream            53.5           19.9              205.0
# 316  Chinstrap   Dream            49.0           19.5              210.0
# 317  Chinstrap   Dream            46.2           17.5              187.0
# 318  Chinstrap   Dream            50.9           19.1              196.0
# 319  Chinstrap   Dream            45.5           17.0              196.0
#
#      body_mass_g     sex  year
# 50        3500.0  female  2008
# ...

# %%
penguins[penguins['year']== 2007]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 297  Chinstrap      Dream            48.5           17.5              191.0
# 298  Chinstrap      Dream            43.2           16.6              187.0
# 299  Chinstrap      Dream            50.6           19.4              193.0
# 300  Chinstrap      Dream            46.7           17.9              195.0
# 301  Chinstrap      Dream            52.0           19.0              197.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins[penguins['species']=='Chinstrap']
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
penguins[penguins['species']=='Adelie']
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
penguin_females = penguins[(penguins['island'] == 'Torgersen')&(penguins['sex'] == 'female')]

# %%
print(penguin_females.shape[0])
#print(food.shape[0])
# Out:
# 24

# %%
penguins['year'].unique()
# Out:
# array([2007, 2008, 2009], dtype=int64)

# %%
penguins_2009 = penguins['year'] == 2009;

# %%
penguins['year'] == 2007;

# %%
penguins_females_Torgersen = penguins[(penguins['island'] == 'Torgersen')&(penguins['sex'] == 'female')   ]

# %%
print(penguins_females_Torgersen.shape[0])
# Out:
# 24

# %%
penguins_females_Torgersen
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# 15   Adelie  Torgersen            36.6           17.8              185.0
# 16   Adelie  Torgersen            38.7           19.0              195.0
# 18   Adelie  Torgersen            34.4           18.4              184.0
# 68   Adelie  Torgersen            35.9           16.6              190.0
# 70   Adelie  Torgersen            33.5           19.0              190.0
# 72   Adelie  Torgersen            39.6           17.2              196.0
# 74   Adelie  Torgersen            35.5           17.5              190.0
# ...

# %%
penguins[
(penguins['island'] == 'Torgersen')&
(penguins['sex'] == 'female')   
]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# 15   Adelie  Torgersen            36.6           17.8              185.0
# 16   Adelie  Torgersen            38.7           19.0              195.0
# 18   Adelie  Torgersen            34.4           18.4              184.0
# 68   Adelie  Torgersen            35.9           16.6              190.0
# 70   Adelie  Torgersen            33.5           19.0              190.0
# 72   Adelie  Torgersen            39.6           17.2              196.0
# 74   Adelie  Torgersen            35.5           17.5              190.0
# ...

# %%
penguins[penguins['island'] == 'Torgersen']
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
penguins[penguins['sex'] == 'female']
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 6       Adelie  Torgersen            38.9           17.8              181.0
# 12      Adelie  Torgersen            41.1           17.6              182.0
# ..         ...        ...             ...            ...                ...
# 335  Chinstrap      Dream            45.6           19.4              194.0
# 337  Chinstrap      Dream            46.8           16.5              189.0
# 338  Chinstrap      Dream            45.7           17.0              195.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins[
(penguins['body_mass_g'] > 3500)& 
(penguins['flipper_length_mm'] > 200)      
]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 90      Adelie      Dream            35.7           18.0              202.0
# 91      Adelie      Dream            41.1           18.1              205.0
# 95      Adelie      Dream            40.8           18.9              208.0
# 101     Adelie     Biscoe            41.0           20.0              203.0
# 123     Adelie  Torgersen            41.4           18.5              202.0
# ..         ...        ...             ...            ...                ...
# 333  Chinstrap      Dream            49.3           19.9              203.0
# 334  Chinstrap      Dream            50.2           18.8              202.0
# 336  Chinstrap      Dream            51.9           19.5              206.0
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins[(penguins['body_mass_g'] > 3500)& (penguins['flipper_length_mm'] > 200) ]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 90      Adelie      Dream            35.7           18.0              202.0
# 91      Adelie      Dream            41.1           18.1              205.0
# 95      Adelie      Dream            40.8           18.9              208.0
# 101     Adelie     Biscoe            41.0           20.0              203.0
# 123     Adelie  Torgersen            41.4           18.5              202.0
# ..         ...        ...             ...            ...                ...
# 333  Chinstrap      Dream            49.3           19.9              203.0
# 334  Chinstrap      Dream            50.2           18.8              202.0
# 336  Chinstrap      Dream            51.9           19.5              206.0
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins[penguins['body_mass_g'] > 3500]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# 6       Adelie  Torgersen            38.9           17.8              181.0
# 7       Adelie  Torgersen            39.2           19.6              195.0
# ..         ...        ...             ...            ...                ...
# 338  Chinstrap      Dream            45.7           17.0              195.0
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins[penguins['flipper_length_mm'] > 200]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 90      Adelie      Dream            35.7           18.0              202.0
# 91      Adelie      Dream            41.1           18.1              205.0
# 95      Adelie      Dream            40.8           18.9              208.0
# 101     Adelie     Biscoe            41.0           20.0              203.0
# 123     Adelie  Torgersen            41.4           18.5              202.0
# ..         ...        ...             ...            ...                ...
# 334  Chinstrap      Dream            50.2           18.8              202.0
# 336  Chinstrap      Dream            51.9           19.5              206.0
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins['year'].max()
# Out:
# 2009

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
penguins[penguins['body_mass_g'] > 5000]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# 159  Gentoo  Biscoe            46.7           15.3              219.0
# 161  Gentoo  Biscoe            46.8           15.4              215.0
# ..      ...     ...             ...            ...                ...
# 267  Gentoo  Biscoe            55.1           16.0              230.0
# 269  Gentoo  Biscoe            48.8           16.2              222.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 153       5700.0    male  2007
# 155       5700.0    male  2007
# ...
