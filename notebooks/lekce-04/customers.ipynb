# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_excel('sales.xlsx')
df.head()
# Out:
#         NÁZEV ZBOŽÍ  FAKTUROVÁNO  MJ  CENA/MJ MĚNA DOKLADU  CENA CELKEM  \
# 0  Váha 7808.70.002            1  ks  36360.0          CZK      29088.0
# 1  Váha 7808.70.002            1  ks  36360.0          CZK      30178.8
# 2  Váha 7808.70.002            1  ks  36360.0          CZK      30906.0
# 3  Váha 7808.70.002            1  ks  32560.0          CZK      32560.0
# 4  Váha 7808.70.002            1  ks  30170.0          CZK      30170.0
#
#    CENA CELKEM PŘED SLEVOU                               NÁZEV PARTNERA  \
# 0                  36360.0                                 Martin Šebek
# 1                  36360.0                            Jindřich Damašek
# 2                  36360.0                   Domov pro seniory Malešice
# 3                  32560.0                     Domov pro seniory Světlo
# 4                  30170.0  Domov Mladá, poskytovatel sociálních služeb
#
#   KÓD SKUPINY KÓD PODSKUPINY       FAKTURA     DATUM REALIZACE       VÝDEJKA  \
# ...
